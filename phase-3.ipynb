# %% [markdown]
# ## Advance operation with Business examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])

print("=== Food Panda Sales analysis ===")
print("\n Sales data shape:",sales_data.shape)
print("\n Sample data for 1st 3 restaurants:",sales_data[:3])
# Out:
# === Food Panda Sales analysis ===
#
#  Sales data shape: (5, 5)
#
#  Sample data for 1st 3 restaurants: [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %%
# total sales per year
print(np.sum(sales_data,axis=0))

yearly_total=np.sum(sales_data[:,1:],axis=0)
print(yearly_total)
# Out:
# [     15  810000  945000 1085000 1240000]
# [ 810000  945000 1085000 1240000]

# %%
# minimum sales per restaurant

min_sales_per_restaurant=np.min(sales_data[:,1:],axis=1)
print("Minimum sales per restaurant:",min_sales_per_restaurant)
# Out:
# Minimum sales per restaurant: [150000 120000 200000 180000 160000]

# %%
# max sales per year

max_sales_per_year=np.max(sales_data[:,1:],axis=0)
print("Maximum sales per year:",max_sales_per_year)
# Out:
# Maximum sales per year: [200000 230000 260000 300000]

# %%
# Average sales per restaurant

avg_sale_per_restaurant=np.mean(sales_data[:,1:],axis=1)
print("Average sales per restaurant:",avg_sale_per_restaurant)
# Out:
# Average sales per restaurant: [200000. 152500. 247500. 225000. 195000.]

# %%
# cumulative sales

cumsum=np.cumsum(sales_data[:,1:],axis=1)
print("Cumulative sales data:\n",cumsum)

plt.figure(figsize=(10,6))
plt.plot(np.mean(cumsum,axis=0))
plt.title("Average Cumulative Sales across all restaurants")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid()
plt.show()
# Out:
# Cumulative sales data:
#  [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
vector1=np.array([1,2,3,4,5])
vector2=np.array([6,7,8,9,10])

print("Vectors addition:",vector1+vector2)
print("Vectors multiplication:",vector1*vector2)
print("Dot product:",np.dot(vector1,vector2))
angle=np.arccos(np.dot(vector1,vector2)/(np.linalg.norm(vector1)*np.linalg.norm(vector2)))
print("Angle between vectors in radians:",angle)
# Out:
# Vectors addition: [ 7  9 11 13 15]
# Vectors multiplication: [ 6 14 24 36 50]
# Dot product: 130
# Angle between vectors in radians: 0.26554161733900966

# %%
restaurant_types=np.array(['biryani','chinese','pizza','burger','cafe'])
vectorized_upper=np.vectorize(str.upper)
print("Uppercase restaurant types:",vectorized_upper(restaurant_types))
# Out:
# Uppercase restaurant types: ['BIRYANI' 'CHINESE' 'PIZZA' 'BURGER' 'CAFE']

# %%
monthly_avg=sales_data[:,1:]/12
print("Monthly average sales per restaurant:\n", monthly_avg)
# Out:
# Monthly average sales per restaurant:
#  [[12500.         15000.         18333.33333333 20833.33333333]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
